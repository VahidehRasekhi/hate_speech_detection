# %% [markdown]
# ## Building Topic Models with the Gensim Library

# %%
import pandas as pd
from tqdm.notebook import tqdm

import gensim

import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train_tweets=pd.read_csv('../data/Dataset 1/clean_train_tweets.csv', encoding="utf-8")
train_tweets
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           id  label                                              tweet  \
# 0          1      0  father dysfunctional selfish drags kids dysfun...
# 1          2      0  thanks lyft credit use cause offer wheelchair ...
# 2          3      0                                     bihday majesty
# 3          4      0                        model love u take u time ur
# 4          5      0                      factsguide society motivation
# ...      ...    ...                                                ...
# 31925  31958      0                                      ate isz youuu
# 31926  31959      0  see nina turner airwaves trying wrap mantle ge...
# 31927  31960      0    listening sad songs monday morning otw work sad
# 31928  31961      1    sikh temple vandalised calgary wso condemns act
# 31929  31962      0                                       thank follow
#
#        length  count
# 0          55      7
# 1          77     11
# 2          14      2
# 3          27      7
# 4          29      3
# ...       ...    ...
# 31925      13      3
# 31926      93     14
# 31927      47      8
# 31928      47      7
# 31929      12      2
#
# [31930 rows x 5 columns]

# %%
offensive_tweets=train_tweets[train_tweets['label']==1]
offensive_tweets
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           id  label                                              tweet  \
# 13        14      1  cnn calls michigan middle school build wall ch...
# 14        15      1  comment australia opkillingbay seashepherd hel...
# 17        18      1                                      retweet agree
# 23        24      1                             lumpy says prove lumpy
# 34        35      1  unbelievable 21st century need something like ...
# ...      ...    ...                                                ...
# 31902  31935      1         lady banned kentucky mall jcpenny kentucky
# 31914  31947      1  omfg offended mailbox proud mailboxpride liber...
# 31915  31948      1   balls hashtag say weasel away lumpy tony dipshit
# 31916  31949      1                 makes ask anybody god oh thank god
# 31928  31961      1    sikh temple vandalised calgary wso condemns act
#
#        length  count
# 13         54      9
# 14         84      7
# 17         13      2
# 23         22      4
# 34         65      8
# ...       ...    ...
# 31902      42      6
# 31914      52      6
# 31915      48      8
# 31916      34      7
# 31928      47      7
#
# [2238 rows x 5 columns]

# %%
from nltk.tokenize import RegexpTokenizer
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
docs = offensive_tweets['tweet'].tolist()
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Split the documents into tokens.
tokenizer = RegexpTokenizer(r'\w+')
for idx in range(len(docs)):
    docs[idx] = docs[idx].lower()  # Convert to lowercase.
    docs[idx] = tokenizer.tokenize(docs[idx])  # Split into words.

# Remove numbers, but not words that contain numbers.
docs = [[token for token in doc if not token.isnumeric()] for doc in docs]

# Remove words that are only one character.
docs = [[token for token in doc if len(token) > 1] for doc in docs]
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Lemmatize the documents.
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
docs = [[lemmatizer.lemmatize(token) for token in doc] for doc in docs]
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
docs[5]
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['let', 'fight', 'love', 'peace']

# %%
# Compute bigrams.
from gensim.models import Phrases

# Add bigrams and trigrams to docs (only ones that appear 20 times or more).
bigram = Phrases(docs, min_count=20)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bigram[docs[10]]
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['mocked', 'obama', 'black', 'brexit']

# %%
# Remove rare and common tokens.
from gensim.corpora import Dictionary

# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.5)
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dictionary[61]
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'police'

# %%
# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 141
# Number of documents: 2238
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
corpus[0]
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(0, 1), (1, 1)]

# %%
from gensim.models import LsiModel
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
lsi = LsiModel(corpus, num_topics=2, id2word = dictionary.id2token)
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
topicid = 7

lsi.show_topic(topicid)
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ''

# %% [markdown]
# ## Nonnegative Matrix Factorization

# %%
from gensim.models import Nmf
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
nmf = Nmf(corpus, num_topics=2, random_state = 321, id2word = dictionary.id2token)
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
topicid = 0

nmf.show_topic(topicid)
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [('like', 0.06069051378760061),
#  ('retweet', 0.04655538754823224),
#  ('black', 0.04253660921633582),
#  ('feel', 0.042497479365314644),
#  ('listen', 0.04021426287157503),
#  ('stomping', 0.03723573884983201),
#  ('miami', 0.03492031892793887),
#  ('listen_retweet', 0.027550684854103405),
#  ('people', 0.026370026103240653),
#  ('like_stomping', 0.025774207462392965)]

# %%
paperid = 3
nmf.get_document_topics(corpus[paperid])
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(1, 1.0)]

# %%
offensive_tweets.loc[34, 'tweet']
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'unbelievable 21st century need something like neverump xenophobia'

# %% [markdown]
# ## Latent Dirichlet Allocation

# %%
# Train LDA model.
from gensim.models import LdaModel

# Set training parameters.
num_topics = 2
chunksize = 2000
passes = 20
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make an index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every,
    random_state=321
)
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis = gensimvis.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(vis, 'lda.html')
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#docs
# Out:
# /Users/vahidehrasekhi/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['father', 'dysfunctional', 'selfish', 'drag', 'kid', 'dysfunction', 'run'],
#  ['thanks',
#   'lyft',
#   'credit',
#   'use',
#   'cause',
#   'offer',
#   'wheelchair',
#   'van',
#   'pdx',
#   'disapointed',
#   'getthanked'],
#  ['bihday', 'majesty'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['factsguide', 'society', 'motivation'],
#  ['huge',
#   'fan',
#   'fare',
#   'big',
#   'talking',
#   'leave',
#   'chaos',
#   'pay',
#   'dispute',
#   'get',
#   'allshowandnogo'],
#  ['camping', 'tomorrow', 'danny'],
#  ['next',
#   'school',
#   'year',
#   'year',
#   'exam',
#   'think',
#   'school',
#   'exam',
#   'hate',
#   'imagine',
#   'actorslife',
#   'revolutionschool',
#   'girl'],
#  ['love',
#   'land',
#   'allin',
#   'cavs',
#   'champion',
#   'cleveland',
#   'clevelandcavaliers'],
#  ['welcome', 'gr8'],
#  ['ireland',
#   'consumer',
#   'price',
#   'index',
#   'mom',
#   'climbed',
#   'previous',
#   'may',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'may_blog',
#   'silver_gold'],
#  ['selfish',
#   'orlando',
#   'standwithorlando',
#   'pulseshooting',
#   'orlandoshooting',
#   'biggerproblems',
#   'selfish',
#   'heabreaking',
#   'value',
#   'love'],
#  ['get', 'see', 'daddy', 'today', '80days', 'gettingfed'],
#  ['cnn',
#   'call',
#   'michigan',
#   'middle',
#   'school',
#   'build',
#   'wall',
#   'chant',
#   'tcot'],
#  ['comment',
#   'australia',
#   'opkillingbay',
#   'seashepherd',
#   'helpcovedolphins',
#   'thecove',
#   'helpcovedolphins'],
#  ['ouch', 'junior', 'angry', 'got', 'junior', 'yugyoem', 'omg'],
#  ['thankful', 'paner', 'thankful', 'positive', 'thankful_positive'],
#  ['retweet', 'agree'],
#  ['friday', 'smile', 'around', 'via', 'ig', 'cooky', 'make', 'people'],
#  ['know', 'essential', 'oil', 'made', 'chemical'],
#  ['euro',
#   'people',
#   'blaming',
#   'ha',
#   'conceded',
#   'goal',
#   'fat',
#   'rooney',
#   'gave',
#   'away',
#   'free',
#   'kick',
#   'knowing',
#   'bale',
#   'hit'],
#  ['sad',
#   'little',
#   'dude',
#   'badday',
#   'coneofshame',
#   'cat',
#   'pissed',
#   'funny',
#   'laugh'],
#  ['product',
#   'day',
#   'happy',
#   'man',
#   'wine',
#   'tool',
#   'weekend',
#   'time',
#   'open',
#   'drink'],
#  ['lumpy', 'say', 'prove', 'lumpy'],
#  ['tgif', 'ff', 'gamedev', 'indiedev', 'indiegamedev', 'squad'],
#  ['beautiful', 'sign', 'vendor', 'upsideofflorida', 'shopalyssas', 'love'],
#  ['smile',
#   'medium',
#   'pressconference',
#   'antalya',
#   'turkey',
#   'sunday',
#   'throwback',
#   'love'],
#  ['great', 'panel', 'mediatization', 'public', 'service', 'ica'],
#  ['happy', 'father', 'day', 'happy_father'],
#  ['people',
#   'went',
#   'nightclub',
#   'good',
#   'night',
#   'man',
#   'action',
#   'mean',
#   'people',
#   'lost',
#   'family',
#   'forever',
#   'rip',
#   'orlando',
#   'good_night'],
#  ['never',
#   'chance',
#   'vote',
#   'presidential',
#   'candidate',
#   'excited',
#   'cycle',
#   'look',
#   'different'],
#  ['alohafriday', 'time', 'exist', 'positivevibes', 'hawaiian'],
#  ['rip',
#   'fellow',
#   'nohern',
#   'ireland',
#   'fan',
#   'sadley',
#   'passed',
#   'away',
#   'tonight',
#   'gawa',
#   'forever',
#   'singing',
#   'cheering',
#   'fire'],
#  ['hard',
#   'monday',
#   'due',
#   'cloudy',
#   'weather',
#   'disabling',
#   'oxygen',
#   'production',
#   'today',
#   'goodnight',
#   'badmonday'],
#  ['unbelievable',
#   '21st',
#   'century',
#   'need',
#   'something',
#   'like',
#   'neverump',
#   'xenophobia'],
#  ['taylorswift',
#   'bull',
#   'dominate',
#   'bull',
#   'direct',
#   'whatever',
#   'want',
#   'bull_dominate',
#   'bull_direct',
#   'whatever_want'],
#  ['morning', 'travelingram', 'dalat', 'ripinkylife'],
#  ['one',
#   'word',
#   'tell',
#   'photoshop',
#   'enoughisenough',
#   'dontphotoshopeverything',
#   'wheresallthenaturalphotos'],
#  ['oh',
#   'cedarpoint',
#   'waited',
#   'hour',
#   'valravn',
#   'line',
#   'stopped',
#   'working',
#   'close'],
#  ['thankful', 'sunshine', 'thankful', 'positive', 'thankful_positive'],
#  ['finally',
#   'finish',
#   'book',
#   'working',
#   'awhile',
#   'bookworm',
#   'ontothenextnovel'],
#  ['yup',
#   'knicks',
#   'fan',
#   'hard',
#   'easier',
#   'nba',
#   'fan',
#   'playoff',
#   'roll',
#   'around'],
#  ['life', 'social', 'networking', 'embrace', 'day'],
#  ['mom', 'share', 'bihday', 'bihday', 'snake', 'see', 'weekend'],
#  ['lovely',
#   'echeveria',
#   'bloom',
#   'flower',
#   'grow',
#   'gardening',
#   'iphonesia',
#   'bliss',
#   'bloom',
#   'basilicabotanica'],
#  ['amazing', 'positive', 'affirmation', 'positive_affirmation'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['whenever', 'im', 'something', 'go', 'wrong'],
#  ['feeling', 'blue', 'illustration'],
#  ['best', 'pa', 'life', 'knowing'],
#  ['abc',
#   'getting',
#   'ready',
#   'remove',
#   'victums',
#   'frm',
#   'pulseclub',
#   'prayfororlando',
#   'getting_ready'],
#  ['bihday', 'got', 'nose', 'job', 'bihday', 'petunia', 'love'],
#  ['concelebrate', 'albanpilgrimage', 'first', 'time', 'first_time'],
#  ['let', 'scum', 'baggery', 'begin'],
#  ['thank',
#   'super',
#   'love',
#   'zpamdelacruz',
#   'wedding',
#   'dolores',
#   'capas',
#   'tarlac'],
#  ['scourge', 'playing', 'baroque', 'piece', 'piano', 'beyond', 'belief'],
#  ['let', 'fight', 'love', 'peace'],
#  ['happy',
#   'father',
#   'day',
#   'mr',
#   'rayos',
#   'video',
#   'father',
#   'day',
#   'rayos',
#   'world',
#   'hotvideo',
#   'video',
#   'happy_father',
#   'father_day'],
#  ['ascot',
#   'time',
#   'babe',
#   'ascot',
#   'fashion',
#   'monochrome',
#   'style',
#   'instahappyday'],
#  ['weekend', 'selfie', 'yolo', 'xoxo', 'like', '4like', 'like_4like'],
#  ['happy',
#   'work',
#   'conference',
#   'right',
#   'mindset',
#   'lead',
#   'culture',
#   'development',
#   'organization',
#   'work',
#   'mindset',
#   'work_conference',
#   'right_mindset',
#   'lead_culture',
#   'development_organization',
#   'work_mindset'],
#  ['christina',
#   'grimmie',
#   'last',
#   'performance',
#   'shot',
#   'via',
#   'christinarip',
#   'voice',
#   'christinagrimmie',
#   'christina_grimmie'],
#  ['ready', 'dance', 'roar', 'preschooler', 'student', 'proud'],
#  ['really', 'hu', 'feeling'],
#  ['wife',
#   'adore',
#   'miss',
#   'poland',
#   'show',
#   'surgery',
#   'name',
#   'bridget',
#   'everything'],
#  ['jealous', 'right', 'chatiado'],
#  ['celebrate',
#   'every',
#   'man',
#   'played',
#   'fatherly',
#   'role',
#   'father',
#   'day',
#   'father_day'],
#  ['sure', 'happy', 'hour'],
#  ['white',
#   'establishment',
#   'blk',
#   'folx',
#   'running',
#   'around',
#   'loving',
#   'promoting',
#   'greatness'],
#  ['good',
#   'morning',
#   'journey',
#   'begin',
#   'travel',
#   'yeah',
#   'thejourneybegins',
#   'hello',
#   'good_morning'],
#  ['luv', 'hottweets', 'like', 'venusexchange'],
#  ['new', 'brochure', 'arrived', 'exciting', 'aworks', 'solution'],
#  ['much',
#   'stuff',
#   'happening',
#   'florida',
#   'first',
#   'orlando',
#   'shooting',
#   'disneygatorattack',
#   'two',
#   'year',
#   'old',
#   'kid',
#   'orlando_shooting',
#   'year_old'],
#  ['ferrari',
#   'sake',
#   'championship',
#   'gp',
#   'clearly',
#   'turning',
#   'point',
#   'rb',
#   'ferrari',
#   'mercs'],
#  ['aced', 'first', 'test', 'proud'],
#  ['seek',
#   'probe',
#   'udtapunjab',
#   'leak',
#   'point',
#   'finger',
#   'amarinder',
#   'aap'],
#  ['wrapping', 'senseaboutmaths', '6th'],
#  ['hey',
#   'white',
#   'people',
#   'call',
#   'people',
#   'white',
#   'race',
#   'identity',
#   'med'],
#  ['might',
#   'shown',
#   'today',
#   'regurgitated',
#   'talking',
#   'point',
#   'name',
#   'calling'],
#  ['sometimes',
#   'raise',
#   'brow',
#   'raise',
#   'bar',
#   'golfstrengthandconditioning',
#   'strong',
#   'felixfoisgolf'],
#  ['greathonour', 'careerconvos'],
#  ['designing',
#   'innovative',
#   'learning',
#   'space',
#   'include',
#   'wateringhole',
#   'cave',
#   'mountaintop',
#   'campfire'],
#  ['altright', 'us', 'insecurity', 'lure', 'men', 'whitesupremacy'],
#  ['carrying',
#   'gun',
#   'helped',
#   'take',
#   'gun',
#   'control',
#   'stop',
#   'black',
#   'market',
#   'terrorism',
#   'get',
#   'worse'],
#  ['use',
#   'power',
#   'mind',
#   'heal',
#   'body',
#   'altwaystoheal',
#   'healthy',
#   'peace',
#   'body_altwaystoheal',
#   'healthy_peace'],
#  ['woohoo', 'week', 'go'],
#  ['far', 'away', 'place', 'family', 'member', 'hus'],
#  ['ready',
#   'rehearse',
#   'tonight',
#   'new',
#   'music',
#   'new',
#   'video',
#   'look',
#   'announcement',
#   'midweek',
#   'newmusic',
#   'watchthisspace',
#   'guitar'],
#  ['monday', 'night', '8p', 'channel', 'finally', 'get', 'see', 'fuss'],
#  ['watching', 'new', 'episode'],
#  ['offline', 'nice', 'long', 'night', 'snapchat', 'redhead', 'vermillionred'],
#  ['thing', 'incredibly', 'people'],
#  ['yes',
#   'received',
#   'acceptance',
#   'letter',
#   'master',
#   'back',
#   'october',
#   'goodtimes',
#   'history'],
#  ['daughter',
#   'riding',
#   'bike',
#   'around',
#   'driveway',
#   'son',
#   'playing',
#   'guitar',
#   'u',
#   'enjoy',
#   'campfire',
#   'summeime',
#   'memory'],
#  ['omg',
#   'loving',
#   'station',
#   'way',
#   'jam',
#   'work',
#   'getting',
#   'work',
#   'done',
#   'course',
#   'memory'],
#  ['always',
#   'hope',
#   'one',
#   'day',
#   'get',
#   'hug',
#   'think',
#   'gonna',
#   'happen',
#   'anytime',
#   'soon'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['couple', 'sex', 'fat', 'naked', 'japanese', 'girl'],
#  ['hump', 'hump', 'day', 'humpers', 'edwardsville', 'pennsylvania'],
#  ['personalised',
#   'gbp',
#   'get',
#   'shop',
#   'cool',
#   'home',
#   'fun',
#   'gbp_get',
#   'shop_cool',
#   'home_fun'],
#  ['truly', 'sick', 'ppl'],
#  ['trump',
#   'calling',
#   'obama',
#   'resign',
#   'orlando',
#   'shooting',
#   'boy',
#   'point',
#   'year',
#   'talk',
#   'change',
#   'orlando_shooting'],
#  ['long', 'nashvilletour', 'nashvilleforever'],
#  ['eur',
#   'usd',
#   'clear',
#   'barrier',
#   'jump',
#   'fresh',
#   'week',
#   'high',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['going', 'la', 'tomorrow'],
#  ['thankful', 'good', 'friend', 'thankful', 'positive', 'thankful_positive'],
#  ['still',
#   'wrap',
#   'head',
#   'around',
#   'fact',
#   'christinagrimmie',
#   'gone',
#   'fact',
#   'man',
#   'destroyed',
#   'prayfororlando'],
#  ['received', 'dis', 'wait', 'sta', 'baking', 'eyelid'],
#  ['playing', 'vigilfororlando', 'harp', 'clonakilty', 'rip', 'via'],
#  ['yes', 'yes', 'yes', 'ihavenofriends', 'someonecomewithme'],
#  ['sunday',
#   'weekend',
#   'relax',
#   'icon',
#   'woman',
#   'sundaymorning',
#   'sunday',
#   'marilynmonroe'],
#  ['interested',
#   'linguistics',
#   'address',
#   'race',
#   'racism',
#   'power',
#   'raciolinguistics',
#   'brings'],
#  ['one',
#   'beloved',
#   'long',
#   'lost',
#   'cd',
#   'recovered',
#   'thanks',
#   'apple',
#   'music'],
#  ['marvel',
#   'song',
#   'musica',
#   'weed',
#   'ripchristina',
#   'adele',
#   'dance',
#   'vine'],
#  ['mocked', 'obama', 'black', 'brexit'],
#  ['spell',
#   'brexit',
#   'referendum',
#   'commerzbank',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['amazing', 'health', 'benefit', 'cucumber', 'healthy', 'altwaystoheal'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['work', 'ofw', 'pinoy', 'followme', 'igers', 'instagood', 'smile', 'love'],
#  ['toradora', 'anime', 'animeedit', 'made', 'breakup', 'alone', 'lonely'],
#  ['lap', 'pool', '10k', 'ride', 'done', 'picked', 'gym', 'membership', 'form'],
#  ['cotd',
#   'polar',
#   'bear',
#   'climb',
#   'racing',
#   'angry',
#   'polar',
#   'bear',
#   'climb',
#   'racing',
#   'polar',
#   'bear',
#   'living',
#   'cold',
#   'place',
#   'looking',
#   'polar_bear',
#   'climb_racing',
#   'angry_polar',
#   'bear_climb',
#   'racing_polar',
#   'bear_living',
#   'cold_place'],
#  ['get', 'angry', 'muslim', 'assassinating', 'much'],
#  ['happy', 'snappy', 'waiting', 'football', 'football', 'snapchat'],
#  ['friday', 'miss', 'fringe', 'qcbags', 'summer'],
#  ['nochebuena', 'lasvegas', 'usa', 'la', 'vega', 'strip'],
#  ['fleurette',
#   'instaboy',
#   'instaman',
#   'sefie',
#   'septum',
#   'friend',
#   'smile',
#   'blackandwhite'],
#  ['sad',
#   'branch',
#   'rainy',
#   'day',
#   'writing',
#   'tear',
#   'flying',
#   'bird',
#   'haiku',
#   '3lines',
#   'micropoetry'],
#  ['yeah', 'new', 'button', 'mail', 'pretty', 'jewelrymaking', 'button'],
#  ['driver',
#   'hit',
#   'female',
#   'moose',
#   'river',
#   'rd',
#   'weston',
#   'moose',
#   'killed',
#   'driver',
#   'ok',
#   'crew',
#   'removing',
#   'animal'],
#  ['afterpas',
#   'made',
#   'japan',
#   'madeinjapan',
#   'eos',
#   'cute',
#   'fun',
#   'cawaii',
#   'love',
#   'strawberry',
#   'tomato'],
#  ['people', 'protesting', 'trump', 'republican', 'trump', 'fuhered'],
#  ['need', 'find', 'way', 'spend', 'time', 'always', 'mind', 'boy', 'guy'],
#  ['update',
#   'social',
#   'analytics',
#   'photooftheday',
#   'igers',
#   'like',
#   'update_social'],
#  ['anyone',
#   'know',
#   'date',
#   'doj',
#   'fbi',
#   'became',
#   'corrupted',
#   'emailgate',
#   'hillary',
#   'shameful',
#   'disgraceful',
#   'ridiculous'],
#  ['stupidity',
#   'make',
#   'even',
#   'negligence',
#   'put',
#   'sachintendulkar',
#   'installation',
#   'going',
#   'take'],
#  ['bihday', '21thbihday', 'bestfriend', 'love'],
#  ['impoant', 'thing', 'enjoy', 'life', 'matter', 'life', 'sho', 'pooh', '4u'],
#  ['happy',
#   'bihday',
#   'chris',
#   'evans',
#   'great',
#   'actor',
#   'human',
#   'chrisevans',
#   'bihday',
#   'happy_bihday'],
#  ['heas',
#   'thought',
#   'prayer',
#   'go',
#   'people',
#   'murdered',
#   'gay',
#   'nightclub',
#   'florida',
#   'thought_prayer'],
#  ['demoing',
#   'guitar',
#   'new',
#   'album',
#   'newalbum',
#   'indie',
#   'guitar',
#   'echobelly'],
#  ['retweeted',
#   'lion',
#   'pro',
#   'tgif',
#   'webmareting',
#   'seo',
#   'community',
#   'management',
#   'weekend'],
#  ['nzd',
#   'usd',
#   'target',
#   'week',
#   'sma',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['pretty',
#   'bad',
#   'bihday',
#   'week',
#   'far',
#   'worst',
#   'ever',
#   'bihdayweeksucks',
#   'bithday'],
#  ['blessed', 'worked', 'sa', 'best', 'leading', 'lady'],
#  ['happiest',
#   'place',
#   'eah',
#   'disneysmagickingdom',
#   'disney',
#   'magickingdom',
#   'disneyland',
#   'orlando'],
#  ['kinda', 'among', 'human'],
#  ['found', 'exclaiming', 'gr8', 'blain', 'hair', 'nite'],
#  ['lt',
#   'listen',
#   'beautiful',
#   'best',
#   'friend',
#   'singing',
#   'amazing',
#   'voice',
#   'lt',
#   'lt',
#   'lt',
#   'lt',
#   'best_friend',
#   'lt_lt',
#   'lt_lt'],
#  ['healthy',
#   'freedom',
#   'effo',
#   'present',
#   'merely',
#   'mean',
#   'effo',
#   'stored',
#   'past',
#   'theodore',
#   'roosevelt'],
#  ['know',
#   'yall',
#   'aint',
#   'going',
#   'know',
#   'love',
#   'commitment',
#   'trust',
#   'faithful'],
#  ['yes',
#   'call',
#   'michelleobama',
#   'gorilla',
#   'racist',
#   'long',
#   'thought',
#   'black',
#   'people',
#   'bet'],
#  ['newarkfestival',
#   'u',
#   'year',
#   'waiting',
#   'show',
#   'sta',
#   '3rd',
#   'year',
#   'running'],
#  ['internet', 'broken', 'watch', 'netflix', 'mochithepug', 'puglife'],
#  ['business', 'usual'],
#  ['hbd',
#   'dick',
#   'suckin',
#   'tequila',
#   'lovin',
#   'slut',
#   'wouldnt',
#   'want',
#   'way',
#   'justalillate',
#   'butstillontime'],
#  ['smaller',
#   'hand',
#   'show',
#   'barry',
#   'probably',
#   'lied',
#   'knicks',
#   'game',
#   'sucked',
#   'golf'],
#  ['good',
#   'morning',
#   'friday',
#   'everyone',
#   'weekend',
#   'goodmorning',
#   'friday',
#   'girl',
#   'love',
#   'florida',
#   'good_morning'],
#  ['challenge', 'aap', 'claim', 'punjabi', 'drugaddicts', 'dare', 'prove'],
#  ['tracerequest',
#   'sending',
#   'deepest',
#   'condolence',
#   'orlando',
#   'gay',
#   'family',
#   'zimbabwe',
#   'gay',
#   'community',
#   'hea',
#   'touched'],
#  ['new', 'selfie', 'guy', 'mato', 'chapones'],
#  ['saturday', 'afternoon', 'chi', 'meet', 'friend'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['soed', 'nut', 'bolt', 'bloke'],
#  ['aww',
#   'yeah',
#   'good',
#   'bing',
#   'bong',
#   'bing',
#   'bong',
#   'aww_yeah',
#   'good_bing',
#   'bong_bing'],
#  ['dawned', 'month', 'seeing', 'live', 'excited', 'vfest', 'summer'],
#  ['happy',
#   '35th',
#   'bihday',
#   'shane',
#   'robe',
#   'watson',
#   'bihday',
#   'shane',
#   'watson',
#   'australia',
#   'cricker'],
#  ['point',
#   'one',
#   'finger',
#   'million',
#   'pointed',
#   'right',
#   'back',
#   'jewishsupremacist'],
#  ['sad',
#   'hear',
#   'announcer',
#   'say',
#   'may',
#   'moved',
#   'player',
#   'one',
#   'two',
#   'lead',
#   'whoknows'],
#  ['radio', 'going', 'coldplay', 'tonight', 'oh', 'yes'],
#  ['think', 'like', 'god', 'coming', 'god', 'keeping'],
#  ['terrorist',
#   'constitutional',
#   'right',
#   'another',
#   'excuse',
#   'republican',
#   'appease',
#   'nra',
#   'gun',
#   'control',
#   'measure'],
#  ['gloucesterrugby'],
#  ['sad', 'happened'],
#  ['everyone',
#   'everything',
#   'sad',
#   'together',
#   'alone',
#   'fine',
#   'dandy',
#   'lonely',
#   'exuberant',
#   'depressed',
#   'halffull',
#   'halfempty'],
#  ['mikeashley',
#   'sposdirectshame',
#   'perhapse',
#   'good',
#   'example',
#   'need',
#   'protect',
#   'workersrights',
#   'within',
#   'europe',
#   'euref',
#   'remain'],
#  ['angry',
#   'bird',
#   'stella',
#   'bad',
#   'princess',
#   'bird',
#   'stella',
#   'bad',
#   'princess',
#   'birdsstellabadprincess',
#   'time',
#   'post',
#   'wed'],
#  ['check', 'incredibly', 'made', 'great', 'memory', 'great', 'people'],
#  ['saw',
#   'shi',
#   'last',
#   'night',
#   'said',
#   'rip',
#   'cared',
#   'really',
#   'last_night'],
#  ['hilarious',
#   'already',
#   'blocked',
#   'asking',
#   'one',
#   'paicularly',
#   'difficult',
#   'question'],
#  ['devastating',
#   'news',
#   'hea',
#   'go',
#   'victim',
#   'family',
#   'orlando',
#   'heabreaking',
#   'victim_family'],
#  ['happiness',
#   'state',
#   'arrive',
#   'manner',
#   'traveling',
#   'margaret',
#   'lee',
#   'runbeck',
#   'happiness',
#   'quote',
#   'inspirational',
#   'quote_inspirational'],
#  ['safe',
#   'way',
#   'heal',
#   'acne',
#   'altwaystoheal',
#   'healthy',
#   'healing',
#   'altwaystoheal_healthy'],
#  ['creating',
#   'right',
#   'beat',
#   'makingbeats',
#   'thursday',
#   'work',
#   'istandard',
#   'akaipro'],
#  ['wedding',
#   'number',
#   'wedding',
#   'weddingpay',
#   'love',
#   'forever',
#   'weddingdress'],
#  ['looking',
#   'forward',
#   'attending',
#   'cipd',
#   'ireland',
#   'conference',
#   'workshop',
#   'cpd',
#   'onemoreday',
#   'looking_forward'],
#  ['finally',
#   'reached',
#   'follower',
#   'twitch',
#   'follower',
#   'hypu',
#   'stream',
#   'tomorrow'],
#  ['word',
#   'free',
#   'use',
#   'em',
#   'cost',
#   'verbal',
#   'abuse',
#   'hu',
#   'love',
#   'adult',
#   'teen'],
#  ['country',
#   'went',
#   'last',
#   'year',
#   'see',
#   'people',
#   'bring',
#   'bomb',
#   'stadium',
#   'come',
#   'everything',
#   'football'],
#  ['thankful', 'cat', 'thankful', 'positive', 'thankful_positive'],
#  ['time',
#   'eat',
#   'bae',
#   'swalscha',
#   'dejeuner',
#   'lunch',
#   'happiness',
#   'love',
#   'amoureux'],
#  ['ilovethesecret',
#   'lawofattraction',
#   'quiz',
#   'love',
#   'happiness',
#   'motivation',
#   'success',
#   'joy',
#   'life'],
#  ['might',
#   'libtard',
#   'libtard',
#   'sjw',
#   'liberal',
#   'politics',
#   'might_libtard',
#   'libtard_sjw',
#   'liberal_politics'],
#  ['go',
#   'pole',
#   'bgp',
#   'rozthediva',
#   'blackgirlspole',
#   'bodyandpole',
#   'live',
#   'love'],
#  ['argentina',
#   'attack',
#   'bull',
#   'game',
#   '3d',
#   'really',
#   'think',
#   'head',
#   'empty',
#   'around',
#   'city',
#   'side',
#   'attack_bull',
#   'game_3d',
#   'really_think',
#   'head_empty',
#   'around_city'],
#  ['self',
#   'serving',
#   'hypocrite',
#   'always',
#   'keep',
#   'eye',
#   'bouncing',
#   'ball',
#   'nimrod',
#   'president'],
#  ['nohcarolina',
#   'bull',
#   'dominate',
#   'bull',
#   'direct',
#   'whatever',
#   'want',
#   'whe',
#   'bull_dominate',
#   'bull_direct',
#   'whatever_want'],
#  ['building',
#   'polar',
#   'bear',
#   'climb',
#   'racing',
#   'angry',
#   'polar',
#   'bear',
#   'climb',
#   'racing',
#   'polar',
#   'bear',
#   'living',
#   'cold',
#   'place',
#   'loo',
#   'polar_bear',
#   'climb_racing',
#   'angry_polar',
#   'bear_climb',
#   'racing_polar',
#   'bear_living',
#   'cold_place'],
#  ['want', 'reelection', 'money', 'ksleg'],
#  ['hea',
#   'orlando',
#   'right',
#   'truly',
#   'cannot',
#   'imagine',
#   'could',
#   'easily',
#   'happened',
#   'anywhere'],
#  ['alreemgroup',
#   'aly',
#   'alshahawy',
#   'ad',
#   'cute',
#   'summer',
#   'photographerdubai',
#   'sun',
#   'hair',
#   'mydubai',
#   'cute_summer'],
#  ['seems', 'like', 'place', 'action', 'montreal'],
#  ['old', 'washed'],
#  ['spirited', 'positive', 'affirmation', 'positive_affirmation'],
#  ['thankful', 'enteainment', 'thankful', 'positive', 'thankful_positive'],
#  ['show', 'truly', 'bad', 'brisbane'],
#  ['wait', 'wimbledon'],
#  ['happy',
#   'man',
#   'success',
#   'model',
#   'entrepreneur',
#   'speaker',
#   'ff',
#   'fresh',
#   'confident',
#   'fashion'],
#  ['gala',
#   'moment',
#   'day',
#   'kid',
#   'bipolar',
#   'frikiegirl',
#   'lucky',
#   'chinatown',
#   'mall',
#   'binondo'],
#  ['really',
#   'take',
#   'piss',
#   'angry',
#   'go',
#   'show',
#   'valued',
#   'complete',
#   'utter',
#   'moron'],
#  ['take', 'trash', 'america', 'voted', 'hate', 'voted', 'voted', 'vot'],
#  ['father',
#   'day',
#   'amazing',
#   'dad',
#   'give',
#   'much',
#   'family',
#   'enjoy',
#   'father_day'],
#  ['magnettherapy',
#   'really',
#   'work',
#   'altwaystoheal',
#   'healing',
#   'healthy',
#   'work_altwaystoheal'],
#  ['sebbo', 'said'],
#  ['eg', 'smile', 'smile', 'egsmile', 'torio'],
#  ['brilliant', 'service', 'kettering', 'branch', 'today', 'customer'],
#  ['screening', 'miss', 'sing', 'song', 'potp', 'shock', 'treatment'],
#  ['way', 'toraya', 'bus', 'alamindah', 'white', 'music', 'carrieunderwood'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['good',
#   'day',
#   'new',
#   'beer',
#   'bridpo',
#   'food',
#   'beer',
#   'fest',
#   'back',
#   'campsite',
#   'drunk',
#   'starstruck',
#   'moved'],
#  ['repost', 'propey', 'ocean', 'summer', 'life', 'family', 'sydney'],
#  ['want',
#   'teach',
#   'love',
#   'like',
#   'never',
#   'felt',
#   'quote',
#   'quote',
#   'love',
#   'pakistan',
#   'allin',
#   'girl',
#   'boy',
#   'fashion',
#   'feeling'],
#  ['thankful', 'thankful', 'positive', 'thankful_positive'],
#  ['omg', 'day', 'left', 'countdown', 'nolefam', 'wait', 'come', 'milan'],
#  ['stone', 'rose', 'done', 'time', 'club', 'day'],
#  ['reason',
#   'two',
#   'people',
#   'stay',
#   'together',
#   'give',
#   'something',
#   'nobody',
#   'else',
#   'hopelly',
#   'great',
#   'day'],
#  ['never',
#   'know',
#   'might',
#   'crush',
#   'wakow',
#   'buzz',
#   'moment',
#   'ride',
#   'love',
#   'crush',
#   'dating',
#   'hookup',
#   'app'],
#  ['friend', 'got', 'engaged'],
#  ['day', 'lef', 'b4', 'end', 'classez', 'yay', 'risay', 'risaypls'],
#  ['thursday', 'may', 'watch', 'say', 'need', 'said'],
#  ['legendary', 'positive', 'affirmation', 'positive_affirmation'],
#  ['united',
#   'state',
#   'america',
#   'rest',
#   'world',
#   'think',
#   'proven',
#   'right',
#   'firearm',
#   'united_state'],
#  ['hold',
#   'open',
#   'door',
#   'woman',
#   'woman',
#   'nice',
#   'thing',
#   'even',
#   'try',
#   'deny'],
#  ['good', 'weekend', 'show', 'thankful', 'blessed', 'jeffreycwilliams'],
#  ['good',
#   'hea',
#   'help',
#   'everyone',
#   'always',
#   'seem',
#   'one',
#   'get',
#   'hu',
#   'buttrue'],
#  ['happiest',
#   'baby',
#   'ive',
#   'ever',
#   'known',
#   'cute',
#   'smile',
#   'babygirl',
#   'beautiful',
#   'niece',
#   'blessed',
#   'xo'],
#  ['ready', 'oneteamlincoln'],
#  ['wait',
#   'carowinds',
#   'ready',
#   'see',
#   'time',
#   'rockthepark',
#   'timetogetmyjesuson'],
#  ['already', 'bought', 'finding', 'dory', 'ticket', 'finding_dory'],
#  ['every', 'minute', 'lose', 'sixty', 'second', 'happiness'],
#  ['sanjapan', 'animeconvention', 'see', 'guy', 'september'],
#  ['question',
#   'day',
#   'excited',
#   'moto',
#   'tech',
#   'announcement',
#   'moto',
#   'question'],
#  ['make',
#   'today',
#   'count',
#   'mondaymotivation',
#   'livelifetothefullest',
#   'healthy',
#   'everydaycounts'],
#  ['happy', 'morning', '8d', 'egree', 'anna', 'classmate', 'friend'],
#  ['would',
#   'able',
#   'suppo',
#   'event',
#   'brentwood',
#   'homesta',
#   'lost',
#   'funding',
#   'may',
#   'close'],
#  ['happy',
#   'little',
#   'people',
#   'happyhappy',
#   'people',
#   'kitten',
#   'cat',
#   'blackkitten'],
#  ['thank', 'much', 'oppounity', 'cherish', 'forever'],
#  ['themeowood', 'puppy'],
#  ['day', 'till'],
#  ['happy', 'pharrell', 'williams', 'pharrellwilliams', 'lyric'],
#  ['happy',
#   'ork',
#   'conference',
#   'right',
#   'mindset',
#   'lead',
#   'culture',
#   'development',
#   'organization',
#   'work',
#   'conference_right',
#   'mindset_lead',
#   'culture_development',
#   'organization_work'],
#  ['lost', 'another', 'member', 'family', 'yesterday', 'gutted', 'rosie'],
#  ['yayyy', 'trailer', '2morrow', 'fever', 'super'],
#  ['watch',
#   'fancy',
#   'tail',
#   'vine',
#   'mad',
#   'mad',
#   'teeth',
#   'bite',
#   'pissed',
#   'dog',
#   'biting',
#   'dogbite',
#   'dogtreat'],
#  ['dreamcatcher',
#   'bull',
#   'dominate',
#   'bull',
#   'direct',
#   'whatever',
#   'want',
#   'bull_dominate',
#   'bull_direct',
#   'whatever_want'],
#  ['ready', 'tomorrow', 'englishteacher', 'teacher', 'ecuador'],
#  ['memory',
#   'wonderful',
#   'dad',
#   'always',
#   'missed',
#   'eternally',
#   'loved',
#   'strong',
#   'greatquotes'],
#  ['dallas',
#   'shooting',
#   'video',
#   'see',
#   'disturbing',
#   'viewer',
#   'discretion',
#   'play',
#   'loop',
#   'ove'],
#  ['itako', 'alone', 'fine', 'little'],
#  ['sunshine',
#   'sticker',
#   'kind',
#   'saturday',
#   'letthembelittle',
#   'childhoodunplugged'],
#  ['wonderful',
#   'day',
#   'today',
#   'calm',
#   'sunny',
#   'chubbygirl',
#   'glass',
#   'finnishgirl',
#   'finn'],
#  ['buka',
#   'bersama',
#   'tma',
#   'family',
#   'yuhuuuuu',
#   'tma',
#   'risha',
#   'meylucky',
#   'others',
#   'mayfair',
#   'townhouse',
#   'pic'],
#  ['love', 'know', 'nationalbestfriendsday', 'true'],
#  ['man',
#   'ran',
#   'governor',
#   'ny',
#   'state',
#   'biggest',
#   'african',
#   'american',
#   'population'],
#  ['stereotyping',
#   'prejudice',
#   'offer',
#   'hope',
#   'solution',
#   'create',
#   'old',
#   'repetitive',
#   'hate',
#   'conflict'],
#  ['get', 'pussy', 'quicker', 'day'],
#  ['probably', 'time', 'come', 'back', 'home', 'ugh'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['anyone',
#   'playing',
#   'voez',
#   'kinda',
#   'love',
#   'game',
#   'game',
#   'gaming',
#   'girlgamer',
#   'voez'],
#  ['many',
#   'pol',
#   'passed',
#   'many',
#   'time',
#   'said',
#   'nothing',
#   'bluelivesmatter',
#   'draintheswamp',
#   'ferguson'],
#  ['sequoia', 'weekend'],
#  ['bitch', 'care', 'eyebrow', 'much', 'makin', 'end', 'week'],
#  ['bham', 'pride', 'paradeready', 'beyou', 'ofbham'],
#  ['fathersday', 'guy', 'play', 'dad', 'love'],
#  ['bihday',
#   'bogummy',
#   'love',
#   'forever',
#   'hope',
#   'happy',
#   'everyday',
#   'good',
#   'night',
#   'good_night'],
#  ['wishing', 'client', 'baby', 'goat', 'cuddle'],
#  ['positivevibes', 'fresh', 'love', 'guy', 'get', 'concord', 'mill', 'mall'],
#  ['conjuring', 'get', 'ready', 'scared', 'tonight', 'readyornot', 'truestory'],
#  ['today',
#   'day',
#   'make',
#   'change',
#   'eliminate',
#   'negativity',
#   'choose',
#   'live',
#   'positive',
#   'lifestyle',
#   'instead'],
#  ['aaahh',
#   'nabilah',
#   'look',
#   'arigatou',
#   'jkt',
#   'happy',
#   'daaay',
#   'iwearbanana'],
#  ['last',
#   'day',
#   'work',
#   'tomorrow',
#   'self',
#   'employed',
#   'monday',
#   'scared',
#   'redditchbizhour'],
#  ['im', 'half', 'boy', 'half', 'man', 'im', 'dumb'],
#  ['happy', 'little', 'boy', 'smile', 'corbinrayp'],
#  ['never',
#   'appropriate',
#   'zero',
#   'idea',
#   'feeling',
#   'right',
#   'scared',
#   'missyou',
#   'whatwasthat'],
#  ['magnificent',
#   'monday',
#   'mondaymorning',
#   'mondaymotivation',
#   'monday',
#   'indraloka'],
#  ['dont',
#   'understand',
#   'designer',
#   'print',
#   'animal',
#   'fabric',
#   'bought',
#   'muzlin',
#   '5b',
#   'sanasafinaz',
#   'noexchangepolicy'],
#  ['maybe', 'happy', 'hour', 'get', 'ending'],
#  ['littlebear',
#   'friend',
#   'joy',
#   'toddlerfriends',
#   'puresweetness',
#   'latergram',
#   'toddlerfun'],
#  ['never',
#   'lost',
#   'loved',
#   'one',
#   'senseless',
#   'violence',
#   'get',
#   'fucking',
#   'opinion',
#   '2nd',
#   'amendment'],
#  ['world', 'heading', 'could', 'lose', 'life', 'leaving', 'home', 'orlando'],
#  ['heard', 'say', 'trying', 'lock', 'shooter', 'kept', 'patron', 'getting'],
#  ['good', 'mood', 'flight', 'munich', 'interview', 'pharrell'],
#  ['first', 'presentation', 'netherlands'],
#  ['made',
#   'u',
#   'proud',
#   'hv',
#   'reading',
#   'ur',
#   'word',
#   'assured',
#   'assoment',
#   'petite',
#   'emotion',
#   'wish',
#   'best'],
#  ['happiness',
#   'v',
#   'joy',
#   'happiness',
#   'temporary',
#   'leaf',
#   'hu',
#   'joy',
#   'last',
#   'forever',
#   'never',
#   'leaf',
#   'real',
#   'tru'],
#  ['twinklatinboys',
#   'na',
#   'slut',
#   'snapshot',
#   'hot',
#   'nasty',
#   'naughty',
#   'sexy',
#   'horny',
#   'shy',
#   'porn',
#   'nude',
#   'kinky',
#   'xxx'],
#  ['people', 'thankful', 'thankful', 'people', 'happy', 'thankfulthursday'],
#  ['creative', 'positive', 'affirmation', 'positive_affirmation'],
#  ['held',
#   'back',
#   'tear',
#   'cried',
#   'happy',
#   'tear',
#   'finally',
#   'leave',
#   'week',
#   'tomorrow',
#   'canadianravers'],
#  ['bihday',
#   'pressie',
#   'mummy',
#   'granny',
#   'michaelkors',
#   'luckygirl',
#   'bihday',
#   'liverpool'],
#  ['stuck',
#   'athens',
#   'instead',
#   'santorini',
#   'said',
#   'windy',
#   'land',
#   'shocking',
#   'service',
#   'every',
#   'level',
#   'since'],
#  ['happy', 'folk', 'first', 'freakshake', 'launch', 'freak', 'yum', 'dalston'],
#  ['huge', 'crowd', 'trump'],
#  ['thankful', 'saturday', 'thankful', 'positive', 'thankful_positive'],
#  ['good', 'god'],
#  ['enjoying',
#   'delicious',
#   'melon',
#   'vegan',
#   'organic',
#   'fresh',
#   'fruit',
#   'organic',
#   'healthy',
#   'healthyliving',
#   'life'],
#  ['first', 'month', 'week', 'day', 'till', 'beginning', 'end', 'sad', 'time'],
#  ['firework', 'weeheeeee'],
#  ['blackpool',
#   'attack',
#   'bull',
#   'game',
#   '3d',
#   'really',
#   'think',
#   'head',
#   'empty',
#   'around',
#   'city',
#   'side',
#   'attack_bull',
#   'game_3d',
#   'really_think',
#   'head_empty',
#   'around_city'],
#  ['fathersday', 'amazing', 'father', 'today'],
#  ['want', 'much', 'ask'],
#  ['ready', 'waiting', 'newblood'],
#  ['sad', 'aunt', 'passed', 'away', 'funeral'],
#  ['horribly', 'ad', 'made', 'u', 'cringe'],
#  ['mind',
#   'robson',
#   'kanu',
#   's6',
#   'decent',
#   'player',
#   'available',
#   'free',
#   'transfer'],
#  ['come', 'better', 'please', 'put', 'shoe', 'unnecessary', 'stress'],
#  ['stalk',
#   'watch',
#   'peon',
#   'poor',
#   'disabled',
#   'kill',
#   'usa',
#   'usa',
#   'used',
#   '2b',
#   'proud',
#   'universe',
#   'care'],
#  ['stephcurry',
#   'outburst',
#   'begs',
#   'question',
#   'christian',
#   'get',
#   'nbafinals'],
#  ['grateful', 'affirmation', 'grateful_affirmation'],
#  ['week',
#   'go',
#   'im',
#   'san',
#   'antonio',
#   'bound',
#   'see',
#   'cant',
#   'wait',
#   'see',
#   'little',
#   'brother',
#   'missyou',
#   'mybrotherskeeper',
#   'cant_wait'],
#  ['listen',
#   'gt',
#   'gt',
#   'gt',
#   'gt',
#   'gt',
#   'gt',
#   'gt',
#   'gt_gt',
#   'gt_gt',
#   'gt_gt'],
#  ['dying',
#   'light',
#   'village',
#   'green',
#   'town',
#   'antisemitism',
#   'hocoschools',
#   'columbiamd',
#   'hocomd'],
#  ['hahaha', 'last', 'friday', 'weird'],
#  ['hey',
#   'noticed',
#   'training',
#   'lover',
#   'ask',
#   'check',
#   'free',
#   'app',
#   'known',
#   'training',
#   'apple'],
#  ['sexy',
#   'fuck',
#   'directioner',
#   'niall',
#   'nialhoranfacts',
#   'niallerwins',
#   'hot',
#   'justindrewbieber',
#   'justindb',
#   'believetou'],
#  ['father',
#   'sday',
#   'say',
#   'love',
#   'dad',
#   'right',
#   'sanya',
#   'whererefreshingbegins'],
#  ['guess',
#   'back',
#   'back',
#   'lifeaftersurgery',
#   'dog',
#   'dogslife',
#   'labrador',
#   'labradorretriever',
#   'lifeofsam'],
#  ['hey',
#   'superspoilt',
#   'may',
#   'want',
#   'check',
#   'latest',
#   'update',
#   'glastofest'],
#  ['bihday', 'sid', 'god', 'bless', 'hav', 'successful', 'career', 'god_bless'],
#  ['nba',
#   'final',
#   'ambivalent',
#   'love',
#   'steph',
#   'thompson',
#   'kyrie',
#   'stinking',
#   'green',
#   'class',
#   'doosh',
#   'lebron',
#   'talk',
#   'guillermo'],
#  ['check',
#   'production',
#   'team',
#   'web',
#   'series',
#   'episode',
#   'edited',
#   'truly',
#   'mep',
#   'webseries'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['never', 'answered', 'statement', 'nazi', 'hatred', 'bigotry', 'found'],
#  ['juneteenth',
#   'independenceday',
#   'food',
#   '4thought',
#   'rich',
#   'ancestral',
#   'heritage',
#   'independence',
#   'hall'],
#  ['river',
#   'gorilla',
#   'simulator',
#   'need',
#   'adapt',
#   'environment',
#   'need',
#   'tear',
#   'city',
#   'material',
#   'gorilla_simulator',
#   'need_adapt',
#   'environment_need',
#   'tear_city'],
#  ['watching',
#   'leadership',
#   'embrace',
#   'kiss',
#   'donald',
#   'as',
#   'pathetic',
#   'pay',
#   'pay',
#   'racism',
#   'hate',
#   'ripgop'],
#  ['love', 'mature', 'age'],
#  ['aww',
#   'yeah',
#   'good',
#   'bing',
#   'bong',
#   'bing',
#   'bong',
#   'aww_yeah',
#   'good_bing',
#   'bong_bing'],
#  ['good', 'feeling', 'happens', 'smile', 'instalike', 'instamood', 'instapic'],
#  ['check',
#   'graffiti',
#   'dublin',
#   'ireland',
#   'music',
#   'vimeo',
#   'movie',
#   'video',
#   'europe',
#   'people',
#   'flow',
#   'fun',
#   'rafalwojcicki'],
#  ['oitnbseason', 'day', 'aaahhhhh'],
#  ['iampossible', 'today', 'extraordinaryladyspeaks', 'starawards', 'ht'],
#  ['sun',
#   'happy',
#   'thursday',
#   'breakfast',
#   'sun',
#   'day',
#   'sunnyday',
#   'sun',
#   'blue'],
#  ['packing',
#   'sneak',
#   'peek',
#   'working',
#   'yellowjackets',
#   'neshl',
#   'bhl',
#   'hockey'],
#  ['tony', 'sunday', 'tonyawards'],
#  ['happy',
#   'father',
#   'day',
#   'dad',
#   'dad',
#   'father',
#   'day',
#   'happy_father',
#   'father_day'],
#  ['theverdict',
#   'idiot',
#   'country',
#   'rock',
#   'bluegrass',
#   'beatles',
#   'love',
#   'pop',
#   'romance'],
#  ['project',
#   'week',
#   'june',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['300dayshappy',
#   'dayseventyseven',
#   'day',
#   'happiness',
#   'love',
#   'lifequotes',
#   'life'],
#  ['little', 'brother', 'higher', 'tolerance', 'alcohol', 'lol'],
#  ['wishing', 'guy', 'bihday', 'blaze', 'say', 'spitting', 'image'],
#  ['thankful', 'hiking', 'trail', 'thankful', 'positive', 'thankful_positive'],
#  ['pay',
#   'meeting',
#   'tackle',
#   'movie',
#   'uncovers',
#   'problem',
#   'want',
#   'world',
#   'know'],
#  ['chill',
#   'relaxing',
#   'piano',
#   'music',
#   'keep',
#   'pet',
#   'quiet',
#   'july',
#   '4th',
#   'firework'],
#  ['might',
#   'libtard',
#   'libtard',
#   'sjw',
#   'liberal',
#   'politics',
#   'might_libtard',
#   'libtard_sjw',
#   'liberal_politics'],
#  ['nothing', 'say', 'merica', 'like', 'tweet'],
#  ['always', 'paratyphoid'],
#  ['today',
#   'lost',
#   'thevoice',
#   'sister',
#   'senselessly',
#   'sing',
#   'love',
#   'death',
#   'people',
#   'stopthehate',
#   'ripchristina'],
#  ['guy', 'concerned', 'twitter', 'brand', 'honest', 'follower'],
#  ['hate',
#   'like',
#   'family',
#   'really',
#   'born',
#   'big',
#   'as',
#   'toxic',
#   'bomb',
#   'mother',
#   'fucker',
#   'give',
#   'fuck',
#   'cuz',
#   'got',
#   'money'],
#  ['get',
#   'get',
#   'get',
#   'enjoy',
#   'music',
#   'today',
#   'free',
#   'apps',
#   'free',
#   'music',
#   'free_apps'],
#  ['best',
#   'lawofattraction',
#   'resource',
#   'healing',
#   'altwaystoheal',
#   'healthy',
#   'idwp',
#   'healing_altwaystoheal'],
#  ['trump',
#   'ny',
#   'co',
#   'chair',
#   'make',
#   'racist',
#   'remark',
#   'michelle',
#   'obama',
#   'p2',
#   'p21',
#   'fyi',
#   'tcot'],
#  ['fan', 'make'],
#  ['music',
#   'therapy',
#   'tool',
#   'healing',
#   'altwaystoheal',
#   'healthy',
#   'healing_altwaystoheal'],
#  ['food', 'make', 'family', 'fight', 'mxm'],
#  ['delicious', 'sangria', 'salud', 'cheer', 'smile', 'pub', 'pembroke'],
#  ['fabulous', 'weekend', 'beautiful', 'soul', 'nofilter'],
#  ['feeling',
#   'overwhelmed',
#   'look',
#   'see',
#   'million',
#   'reason',
#   'happy',
#   'love',
#   'craig'],
#  ['back', 'day', 'job', 'shane', 'lowry'],
#  ['hour', 'right', 'bottle', 'drink', '7pm', 'chippewa', 'st', 'buffalo'],
#  ['ana',
#   'nimra',
#   'farishta',
#   'mawia',
#   'khushal',
#   'number',
#   'mark',
#   'obtained',
#   'damn',
#   'high'],
#  ['monday',
#   'empty',
#   'without',
#   'bachelorette',
#   'thebachelorette',
#   'empty',
#   'nowine'],
#  ['suppoing',
#   'family',
#   'god',
#   'chivalry',
#   'tradition',
#   'pride',
#   'one',
#   'heritage',
#   'controversial'],
#  ['pic',
#   'say',
#   'otherwise',
#   'young',
#   'girl',
#   'confined',
#   'kitchen',
#   'void',
#   'meaning',
#   'beyond',
#   'cheap',
#   'publicity',
#   'topoli'],
#  ['good', 'night', 'faith', 'ever', 'vaitacacommafiasdv', 'good_night'],
#  ['love', 'simply', 'love', 'love', 'success', 'work', 'business'],
#  ['lunchtime',
#   'mom',
#   'torrington',
#   'lunch',
#   'afterschool',
#   'instadaily',
#   'yummy',
#   'withmom'],
#  ['sister',
#   'even',
#   'know',
#   'watching',
#   'argue',
#   'nigga',
#   'waiting',
#   'say',
#   'wrong',
#   'shit'],
#  ['ride',
#   'ride',
#   'back',
#   'done',
#   'cycling',
#   'sunset',
#   'ride',
#   'bike',
#   'fitness',
#   'cardio',
#   'dese'],
#  ['well', 'gonna', 'go', 'see', 'adtr', 'bae'],
#  ['tagsforlikes',
#   'food',
#   'friend',
#   'summer',
#   'swag',
#   'quote',
#   'love',
#   'god',
#   'girl',
#   'weekend',
#   'polaroid',
#   'followme',
#   'teen',
#   'win',
#   'job'],
#  ['payintheusa',
#   'polar',
#   'bear',
#   'climb',
#   'racing',
#   'angry',
#   'polar',
#   'bear',
#   'climb',
#   'racing',
#   'polar',
#   'bear',
#   'living',
#   'cold',
#   'place',
#   'polar_bear',
#   'climb_racing',
#   'angry_polar',
#   'bear_climb',
#   'racing_polar',
#   'bear_living',
#   'cold_place'],
#  ['healthy', 'fam'],
#  ['dream',
#   'palace',
#   'move',
#   'already',
#   'stellar',
#   'girl',
#   'dreamy',
#   'goodmorning',
#   'day'],
#  ['im', 'waiting', 'follow', 'since', 'factor'],
#  ['fault', 'use', 'pointscore'],
#  ['week',
#   'staed',
#   'kinda',
#   'lame',
#   'getting',
#   'better',
#   'yay',
#   'wednesdaywisdom'],
#  ['forever',
#   'young',
#   'man',
#   'luks',
#   'hot',
#   'wen',
#   'temper',
#   'alwys',
#   'ur',
#   'fan',
#   'till',
#   'lst',
#   'breath'],
#  ['worry', 'bee'],
#  ['double',
#   'tap',
#   'follow',
#   'beautiful',
#   'smooth',
#   'lifestyle',
#   'skin',
#   'instasize',
#   'f4f',
#   'fashion'],
#  ['lawofattraction',
#   'healing',
#   'loa',
#   'healthy',
#   'well',
#   'idwp',
#   'lawofattraction_healing'],
#  ['oil',
#   'turn',
#   'flat',
#   'eyeing',
#   'eia',
#   'inventory',
#   'data',
#   'fuher',
#   'direction',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['training', 'new', 'employee', 'fun', 'newblood'],
#  ['first',
#   'bihday',
#   'puppy',
#   'eloise',
#   'sweetbabins',
#   'dog',
#   'growingup',
#   'cute',
#   'bihdaygirl'],
#  ['pig', 'burn', 'alive', 'saskatchewan', 'barn', 'fire', 'video'],
#  ['never',
#   'convince',
#   'american',
#   'right',
#   'bear',
#   'prayfororlando',
#   'guncontrol'],
#  ['beautiful', 'lady', 'blessing', 'know', 'smile', 'lovethem'],
#  ['today',
#   'baba',
#   'siddique',
#   'ifftar',
#   'pay',
#   'mumbai',
#   'dono',
#   'ayenge',
#   'see'],
#  ['hand', 'ombre', 'blue'],
#  ['wait', 'go', 'see', 'warcraft', 'ugh', 'warcraft'],
#  ['cousin', 'reunited', 'family', 'fun', 'wellness'],
#  ['audience', 'duane', 'henry', 'insightful'],
#  ['train', 'moved', 'binge', 'tweeting'],
#  ['lover',
#   'stop',
#   'angry',
#   'visit',
#   'u',
#   'gt',
#   'gt',
#   'gt',
#   'lover',
#   'friend',
#   'astrologer',
#   'love',
#   'lover_stop',
#   'angry_visit',
#   'gt_gt',
#   'gt_lover',
#   'friend_astrologer'],
#  ['blocked',
#   'troll',
#   'promise',
#   'blacklivesmatter',
#   'let',
#   'nonsensical',
#   'rant',
#   'boo'],
#  ['father', 'day', 'dad', 'one', 'heaven', 'father_day'],
#  ['sdl', '326am', 'june'],
#  ['creepy',
#   'awesome',
#   'baboon',
#   'climbing',
#   'fire',
#   'escape',
#   'like',
#   'human',
#   'summev',
#   'zoo'],
#  ['use',
#   'power',
#   'mind',
#   'heal',
#   'body',
#   'altwaystoheal',
#   'healthy',
#   'body_altwaystoheal'],
#  ['dude', 'tiger', 'roar', 'tiger', 'annaswelshzoo', 'bihdaycelebrations'],
#  ['laugh', 'happy', 'laugh', 'william', 'james', 'xtra'],
#  ['happy',
#   'sunday',
#   'everyone',
#   'think',
#   'today',
#   'going',
#   'good',
#   'day',
#   'positivevibes',
#   'sunshine',
#   'sunday'],
#  ['talk',
#   'way',
#   'organization',
#   'dehumanize',
#   'u',
#   'never',
#   'held',
#   'accountable'],
#  ['stuck', 'rat', 'race', 'find', 'freedom', 'masterkeyexperience'],
#  ['study', 'face', 'pizza', 'stole', 'roommate', 'idea', 'taking', 'pic'],
#  ['dinner', 'sister', 'sisteradventures', 'sister', 'ilovemysister'],
#  ['else', 'planning', 'watching', 'tomorrow'],
#  ['usn', 'rifle', 'day', 'snowed', 'ar', 'closest', 'ever', 'got', 'navy'],
#  ['euro',
#   'bbc',
#   'pundit',
#   'make',
#   'prediction',
#   'france',
#   'euro',
#   'sta',
#   'today'],
#  ['happy', 'happiness', 'minion'],
#  ['elder', 'scroll', 'many', 'year', 'wah', 'wah', 'bethesda', 'e3', 'e32016'],
#  ['poor',
#   'tiggy',
#   'little',
#   'bit',
#   'cheeky',
#   'jax',
#   'soa',
#   'throwbackthursday'],
#  ['cannot', 'wait', 'eurogamer', 'year', 'pumped', 'eurogamer', 'cannot_wait'],
#  ['work',
#   'russell',
#   'beckwith',
#   'soon',
#   'staytuned',
#   'friend',
#   'lyle',
#   'tapfoags'],
#  ['nazi',
#   'studied',
#   'american',
#   'race',
#   'law',
#   'inspiration',
#   'ushistory',
#   'eugenics'],
#  ['sharing',
#   'ice',
#   'cream',
#   'sun',
#   'love',
#   'outdoors',
#   'picnic',
#   'summer',
#   'family',
#   'daughter',
#   'father',
#   'desse',
#   'icecream',
#   'ice_cream'],
#  ['nothing',
#   'like',
#   'river',
#   'island',
#   'sale',
#   'shopping',
#   'spree',
#   'cheer',
#   'retailtherapy',
#   'riverisland',
#   'shoppingqueen',
#   'alwayscheersyouup'],
#  ['cleaning',
#   'ze',
#   'house',
#   'zoing',
#   'ziy',
#   'laundry',
#   'finally',
#   'free',
#   'fever',
#   'cold',
#   'happy',
#   'cleaning',
#   'laundryday'],
#  ['new',
#   'listing',
#   'ebay',
#   'woohoo',
#   'sell',
#   'selling',
#   'buy',
#   'shop',
#   'shopping'],
#  ['thankful', 'challenge', 'thankful', 'positive', 'thankful_positive'],
#  ['chilled', 'night', 'ice', 'cream', 'grown', 'up2', 'chilled', 'ice_cream'],
#  ['biherism',
#   'absolutely',
#   'originated',
#   'hateful',
#   'bigotry',
#   'altright',
#   'hatred',
#   'african',
#   'american',
#   'potus',
#   'theresistance'],
#  ['sweet', 'instagood', 'idola', 'idol', 'followme', 'selfie'],
#  ['tragedy',
#   'america',
#   'first',
#   'killing',
#   'christinagrimmie',
#   'orlando',
#   'america',
#   'safe',
#   'place',
#   'today'],
#  ['brexit',
#   'angst',
#   'factor',
#   'helping',
#   'drive',
#   'interest',
#   'rate',
#   'germany',
#   'japan',
#   'bbh',
#   'blog',
#   'silver',
#   'gold',
#   'blog_silver'],
#  ['fab',
#   'interesting',
#   'day',
#   'eacbpm',
#   'dash',
#   'quiet',
#   'place',
#   'dial',
#   'iiba',
#   'emea',
#   'region',
#   'meeting',
#   'busy'],
#  ['kayak',
#   'sup',
#   'snorkel',
#   'swim',
#   'whatever',
#   'pleasure',
#   'put',
#   'together',
#   'alohabeachbus',
#   'hawaii',
#   'explore'],
#  ['hold', 'man', 'year', 'watch', 'change', 'hear', 'say', 'loyalty'],
#  ['back',
#   'going',
#   'tacloban',
#   'see',
#   'ya',
#   'later',
#   'great',
#   'traveling',
#   'tacloban',
#   'city',
#   'catbalogan'],
#  ['feel', 'olympics', 'medal'],
#  ['angry',
#   'bird',
#   'il',
#   'film',
#   'download',
#   'ita',
#   '720p',
#   'hdtc',
#   'bird',
#   'download',
#   'film',
#   'il',
#   'ita'],
#  ['sunday',
#   'photo',
#   'model',
#   'urbex',
#   'topless',
#   'tit',
#   'mono',
#   'retweet',
#   'sexy',
#   'heel',
#   'ace'],
#  ['fo',
#   'woh',
#   'officer',
#   'viral',
#   'arrest',
#   'video',
#   'rude',
#   'racist',
#   'chief',
#   'crime',
#   'officer'],
#  ['saturday', 'friend'],
#  ['yayyyy',
#   'friend',
#   'got',
#   'married',
#   'today',
#   'congratulation',
#   'guy',
#   'shegotmarried'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['lewis', 'remains', 'perfect', 'ranger', 'announcer', 'gonna', 'stroke'],
#  ['chris', 'back', 'soccer', 'missing', 'spring', 'season', 'broken'],
#  ['train', 'ticket', 'booked', 'opera', 'week', 'wale'],
#  ['beautiful', 'day', 'sun', 'fun', 'beachpark', 'beach', 'park', 'sun_fun'],
#  ['big', 'screen', 'fitted', 'right', 'euro'],
#  ['love',
#   'story',
#   'happy',
#   'ending',
#   'anime',
#   'love',
#   'story',
#   'ending',
#   'like',
#   '4like',
#   'like_4like'],
#  ['poet',
#   'bull',
#   'dominate',
#   'bull',
#   'direct',
#   'whatever',
#   'want',
#   'sta',
#   'bull_dominate',
#   'bull_direct',
#   'whatever_want'],
#  ['tranquil', 'positive', 'affirmation', 'positive_affirmation'],
#  ['name', 'upcoming', 'new', 'track', '2pm', 'kpop'],
#  ['best',
#   'essentialoils',
#   'anxiety',
#   'healthy',
#   'peace',
#   'altwaystoheal',
#   'best_essentialoils',
#   'anxiety_healthy',
#   'peace_altwaystoheal'],
#  ['wow',
#   'people',
#   'child',
#   'nothing',
#   'better',
#   'insult',
#   'people',
#   'twitter'],
#  ['thinking',
#   'maybe',
#   'bought',
#   'instead',
#   'gettingold',
#   'becomingboring',
#   'notborderlands',
#   'goblizzard'],
#  ['fact',
#   'album',
#   'hour',
#   'away',
#   'dripping',
#   'losing',
#   'mind',
#   'fatkidinacandystore'],
#  ['ryderrideu',
#   'see',
#   'c2c',
#   'cum',
#   'together',
#   'snapshot',
#   'young',
#   'shy',
#   'kinky',
#   'wet',
#   'porn',
#   'hot',
#   'xxx',
#   'horny'],
#  ['snapchat',
#   'gaby',
#   'china',
#   'love',
#   'girl',
#   'snapchat',
#   'flower',
#   'instasmile',
#   'instalove'],
#  ['brilliant', 'positive', 'affirmation', 'positive_affirmation'],
#  ['true',
#   'nigga',
#   'dont',
#   'go',
#   'looking',
#   'apaments',
#   'go',
#   'look',
#   'shoe',
#   'jewelry'],
#  ['safe',
#   'way',
#   'heal',
#   'acne',
#   'altwaystoheal',
#   'healthy',
#   'healing',
#   'altwaystoheal_healthy'],
#  ['msgapparelstoday', 'special', 'u', 'father', 'day', 'father_day'],
#  ['camping', 'next', 'weekend', 'lovecamping', 'brownwood'],
#  ['grateful', 'affirmation', 'grateful_affirmation'],
#  ['forever',
#   'bestie',
#   'karaoke',
#   'friend',
#   'friendship',
#   'love',
#   'nofilter',
#   'instacool',
#   'instagood'],
#  ['absolutely',
#   'love',
#   'place',
#   'fantastic',
#   'welcome',
#   'carlos',
#   'receptionist',
#   '5th',
#   'time',
#   'room',
#   'request',
#   'granted',
#   'usual'],
#  ['headed', 'thealter', 'peculiar', 'family'],
#  ['u',
#   'retail',
#   'sale',
#   'control',
#   'group',
#   'likely',
#   'rose',
#   'may',
#   'danske',
#   'bank',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['happy',
#   'father',
#   'day',
#   'love',
#   'life',
#   'best',
#   'father',
#   'world',
#   'fathersday',
#   'love',
#   'happy_father'],
#  ['coolestlifehack', 'world', 'smallest', 'snake', 'motivation'],
#  ['shockingly',
#   'increasingly',
#   'violent',
#   'world',
#   'live',
#   'uk',
#   'gun',
#   'control',
#   'law',
#   'feel',
#   'mp',
#   'family',
#   'friend'],
#  ['funny', 'simply', 'truestory'],
#  ['happy',
#   'bihday',
#   'brithday',
#   'day',
#   'holiday',
#   'monday',
#   'menmodels',
#   'happy_bihday'],
#  ['saddened',
#   'one',
#   'thought',
#   'groom',
#   'position',
#   'asking',
#   'opinion',
#   'issue'],
#  ['ukrainian',
#   'athlete',
#   'grosseto',
#   'watching',
#   'livestream',
#   'without',
#   'seeing'],
#  ['new', 'season', 'oitnb', 'stas', 'tonight', 'oitnbseason'],
#  ['excited',
#   'side',
#   'cuain',
#   'tonight',
#   'looking',
#   'forward',
#   'seeing',
#   'broadway',
#   'looking_forward'],
#  ['quay', 'collab', 'say', 'sold', 'noooo', 'whyyyy', 'loveyoudesi'],
#  ['finally', 'get', 'jordan', 'get', 'paid', 'wear', 'lowtops'],
#  ['impressive', 'positive', 'affirmation', 'positive_affirmation'],
#  ['father', 'day', 'father', 'making', 'happen', 'salute', 'father_day'],
#  ['view',
#   '27th',
#   'floor',
#   'nyc',
#   'newyorkcity',
#   'myview',
#   'girl',
#   'wine',
#   'fridaynight'],
#  ['discussing', 'republican', 'thing', 'critiquing', 'ignore', 'consequence'],
#  ['got', 'school', 'tomorrow', 'last', 'integration'],
#  ['amen', 'truth', 'always', 'lt', 'lt', 'love', 'blessed', 'lt_lt'],
#  ['stamford', 'kid', 'got', 'month', 'rape', 'boredom', 'minute', 'action'],
#  ['let',
#   'colorized',
#   'life',
#   'rainbow',
#   'danian',
#   'love',
#   'colour',
#   'rainbow',
#   'depok'],
#  ['aiel',
#   'aielmaharashtra',
#   'rude',
#   'customer',
#   'care',
#   'executive',
#   'make',
#   'want',
#   'switch',
#   'loyalty',
#   'another',
#   'provider',
#   'irritated'],
#  ['hi', 'teddy', 'corpuz', 'rocksteddy', 'band', 'enjoy', 'idol', 'omg'],
#  ['wow',
#   'great',
#   'daughter',
#   'send',
#   'father',
#   'right',
#   'father',
#   'day',
#   'cheapshot',
#   'lowblow',
#   'shame',
#   'father_day'],
#  ['reason',
#   'happy',
#   'kid',
#   'mid',
#   'tantrum',
#   'parenting',
#   'tantrum',
#   'toddler',
#   'calm',
#   'mindfulness',
#   'strong'],
#  ['truthful', 'positive', 'affirmation', 'positive_affirmation'],
#  ['yup',
#   'siri',
#   'macos',
#   'wwdc',
#   'woot',
#   'next',
#   'work',
#   'listening',
#   'skill'],
#  ['diy',
#   'done',
#   'dresser',
#   'nicknack',
#   'newelectricscrewdriver',
#   'brockely',
#   'london'],
#  ['black',
#   'feel',
#   'like',
#   'stomping',
#   'retweet',
#   'tampa',
#   'miami',
#   'black_feel',
#   'like_stomping',
#   'retweet_tampa'],
#  ['thats',
#   'problem',
#   'one',
#   'police',
#   'officer',
#   'need',
#   'bigger',
#   'gun',
#   'perhaps',
#   'one',
#   'tank',
#   'soldier'],
#  ['father', 'day', 'friend', 'father_day'],
#  ['choice', 'fall', 'always', 'write', 'candidate'],
#  ['ending'],
#  ['get',
#   'know',
#   'team',
#   'behind',
#   'app',
#   'keeping',
#   'tummy',
#   'june',
#   'issue',
#   'bazaarmag'],
#  ['actually', 'going', 'fishing', 'today', 'somewhere', 'nice'],
#  ['cute', 'look', 'like', 'doll', 'look_like'],
#  ['im'],
#  ['love',
#   'vacation',
#   'enjoy',
#   'greece',
#   'crete',
#   'sabinedrift',
#   'chillinn',
#   'blondegirl',
#   'bluedress'],
#  ['unreal',
#   'advisor',
#   'refuse',
#   'take',
#   'payment',
#   'say',
#   'wait',
#   'pcn',
#   'customer',
#   'service',
#   'ur',
#   'site',
#   'wasnt',
#   'working'],
#  ['gameready', 'forza', 'horizon', 'pc', 'time', 'live'],
# ...
#   'lot',
#   'pain',
#   'many',
#   'people',
#   'vengeance',
#   'option',
#   'let',
#   'comfo'],
#  ['cuteness',
#   'overloaded',
#   'let',
#   'life',
#   'fill',
#   'love',
#   'sweetness',
#   'live',
#   'long',
#   'married',
#   'life'],
#  ['heading', 'graduation', 'mechtechplumbing', 'futureplumber', 'proudmama'],
#  ['possible', 'speak', 'topic', 'without', 'bringing', 'race', 'bigot'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['much',
#   'terribly',
#   'news',
#   'weekend',
#   'orlando',
#   'christinagrimmie',
#   'prayer'],
#  ['make', 'innovative', 'nous'],
#  ['update',
#   'social',
#   'analytics',
#   'instalike',
#   'tbt',
#   'yoga',
#   'summer',
#   'fun',
#   'update_social'],
#  ['rushlimbaugh', 'incredibly', 'obama', 'impression', 'via'],
#  ['people', 'failing', 'fellow', 'citizen'],
#  ['staing', 'pack', 'move', 'newflat'],
#  ['first',
#   'love',
#   'may',
#   'make',
#   'feel',
#   'like',
#   'love',
#   'cheese',
#   'shotermlongdistance',
#   'feel_like'],
#  ['youtu', 'bed', 'two', 'get', 'friendship'],
#  ['want',
#   'kind',
#   'poor',
#   'sin',
#   'despise',
#   'anyone',
#   'jesus',
#   'faith',
#   'believe',
#   'wisdom'],
#  ['nice', 'life', 'done', 'trying', 'lovequotes'],
#  ['latest', 'positivementalattitude', 'thanks', 'positive'],
#  ['want',
#   'spark',
#   'serious',
#   'debate',
#   'gun',
#   'violence',
#   'release',
#   'photo',
#   'body',
#   'inside',
#   'club',
#   'orlandoshooting',
#   'gunviolence'],
#  ['arrived', 'blagoevgrad', 'fo', 'zaz', 'conce', 'feeling', 'umbrelas'],
#  ['number', 'leader', 'coming'],
#  ['see', 'tcashowroom', 'yesterday'],
#  ['mean', 'mean', 'like'],
#  ['great',
#   'way',
#   'spend',
#   'saturday',
#   'relaxation',
#   'positivevibes',
#   'california',
#   'cakesbytheocean'],
#  ['eur',
#   'usd',
#   'could',
#   'test',
#   'near',
#   'term',
#   'westpac',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['money',
#   'campaign',
#   'asking',
#   '100k',
#   'donation',
#   'midnight',
#   'fight',
#   'hrc',
#   'ad',
#   'buy',
#   'brokedonald',
#   'lyindon'],
#  ['today',
#   'call',
#   'champagne',
#   'friday',
#   'fridayfeeling',
#   'friyay',
#   'goodweek',
#   'client',
#   'hair'],
#  ['rightly', 'gop', 'hate', 'trump', 'obama'],
#  ['sunday', 'hug'],
#  ['u', 'selfie', 'myfriend', 'loveher', 'giannena', 'smile', 'thecomeback'],
#  ['moment',
#   'decided',
#   'needed',
#   'switch',
#   'control',
#   'life',
#   'response',
#   'default'],
#  ['playing', 'yiruma', 'kiss', 'rain', 'music', 'song', 'music_song'],
#  ['simple',
#   'true',
#   'becoming',
#   'capable',
#   'burnsurvivor',
#   'dolbf',
#   'motivation',
#   'motivate'],
#  ['back', 'missed', 'greatfultogod', 'beendoinggreat', 'selfie'],
#  ['repeat',
#   'put',
#   'dog',
#   'hot',
#   'car',
#   'leave',
#   'heat',
#   'keep',
#   'home',
#   'fuck',
#   'sake',
#   'dog'],
#  ['splendid', 'nosie', 'probably', 'year', 'wrc', 'rallypoland'],
#  ['hour',
#   'go',
#   'music',
#   'video',
#   'released',
#   'music',
#   'edinburgh',
#   'scotland',
#   'band',
#   'musicvideo'],
#  ['confirmed', 'dead', 'according', 'farrah', 'gray', 'pulseshooting'],
#  ['look', 'journey', 'left', 'right', 'foot', 'stage'],
#  ['black',
#   'professor',
#   'make',
#   'assumption',
#   'entire',
#   'race',
#   'whilst',
#   'speaking',
#   'entire',
#   'race',
#   'next',
#   'week',
#   'jew',
#   'next_week'],
#  ['back',
#   'music',
#   'playing',
#   'michael',
#   'jackson',
#   'lost',
#   'child',
#   'unificationsday',
#   'may',
#   'god',
#   'child',
#   'family',
#   'smile'],
#  ['drakeandjosh',
#   'buffalo',
#   'simulation',
#   'buffalo',
#   'take',
#   'vicinity',
#   'home',
#   'wa',
#   'buffalo_simulation',
#   'buffalo_take',
#   'vicinity_home'],
#  ['trumpusa',
#   'call',
#   'u',
#   'homophobic',
#   'misogynist',
#   'really',
#   'saying',
#   'jealous',
#   'u'],
#  ['think', 'suspend', 'indefininetly', 'racist', 'staff'],
#  ['sat', 'alone', 'let', 'sad', 'sigh', 'openrp', 'bored'],
#  ['good',
#   'morning',
#   'manchester',
#   'quick',
#   'preview',
#   'new',
#   'gin',
#   'launching',
#   'soon',
#   'one',
#   'good_morning'],
#  ['tried',
#   'new',
#   'trailn',
#   '2v3',
#   'today',
#   'although',
#   'feel',
#   'similar',
#   'v2',
#   'v3',
#   'smoother',
#   'feel',
#   'great'],
#  ['kiki',
#   'felt',
#   'ignored',
#   'today',
#   'make',
#   'kiki',
#   'dance',
#   'kikidance',
#   'miabbook'],
#  ['source',
#   'inspiration',
#   'ideal',
#   'lyf',
#   'baba',
#   'father',
#   'day',
#   'father_day'],
#  ['congrats',
#   'thomas',
#   'new',
#   'beautiful',
#   'home',
#   'tehaleh',
#   'welcome',
#   'lennar',
#   'family',
#   'homeowner'],
#  ['miss', 'day', 'friend', 'played', 'xbox'],
#  ['new', 'case', 'scraggly', 'hair'],
#  ['loving',
#   'dincwear',
#   'mum',
#   'da',
#   'word',
#   'straight',
#   'saturday',
#   'brickingit'],
#  ['bihday', 'sexy', 'girl', 'girl', 'top', 'boy', 'naked'],
#  ['one',
#   'majority',
#   'fan',
#   'like',
#   'salty',
#   'gsw',
#   'fan',
#   'needed',
#   'someone'],
#  ['changing',
#   'daily',
#   'basis',
#   '14weeks',
#   'handover',
#   'network',
#   'team',
#   'soon',
#   'av'],
#  ['coming', 'singapore'],
#  ['sma',
#   'baby',
#   'sock',
#   'gbp',
#   'get',
#   'shop',
#   'cool',
#   'home',
#   'fun',
#   'gbp_get',
#   'shop_cool',
#   'home_fun'],
#  ['liked', 'video', 'sjw', 'retard', 'want'],
#  ['woh', 'wait', 'doubledown', 'wife', 'veganbeerfest', 'vegan'],
#  ['lmfao', 'deadass'],
#  ['amazing', 'interview', 'bjmckenzie', 'born', '2win', 'bjmuzic'],
#  ['boasty',
#   'tuesday',
#   'last',
#   'night',
#   'boom',
#   'boom',
#   'harry',
#   'hype',
#   'say',
#   'get',
#   'last_night'],
#  ['bihday',
#   'balayya',
#   'even',
#   'age',
#   'mass',
#   'look',
#   'craze',
#   'fan',
#   'screen',
#   'romance',
#   'legend',
#   'jaibalayya'],
#  ['woohoo',
#   'kingslanding',
#   'highlandreserve',
#   'house',
#   'family',
#   'building',
#   'ourhome'],
#  ['outlining', 'theme', 'would', 'poem', 'haha'],
#  ['decor',
#   'buffalo',
#   'simulation',
#   'buffalo',
#   'take',
#   'vicinity',
#   'home',
#   'way',
#   'buffalo_simulation',
#   'buffalo_take',
#   'vicinity_home'],
#  ['sold',
#   'one',
#   'two',
#   'painting',
#   'going',
#   'get',
#   'beautiful',
#   'new',
#   'home',
#   'week',
#   'sold'],
#  ['msg',
#   'hope',
#   'newyear',
#   'business',
#   'end',
#   'endof',
#   'tedtalks',
#   'tedatibm'],
#  ['slag', 'child', 'love', 'show', 'really'],
#  ['safe',
#   'say',
#   'missing',
#   'marbs',
#   'sitting',
#   'home',
#   'watching',
#   'euro',
#   'listening',
#   'rain',
#   'depressing',
#   'bringbackhappiness'],
#  ['brainwashed', 'left', 'allowing', 'terrorist', 'come', 'america', 'kill'],
#  ['gd',
#   'morning',
#   'gdragon',
#   'gd',
#   'kwonjiyong',
#   'jiyong',
#   'vip',
#   'bigbang',
#   'handsome',
#   'cute',
#   'love'],
#  ['friendszxc'],
#  ['day', 'till', 'vacation'],
#  ['secret',
#   'happy',
#   'marriage',
#   'finding',
#   'people',
#   'le',
#   'attractive',
#   'repo'],
#  ['python',
#   'concurrency',
#   'best',
#   'friend',
#   'code',
#   'restructure',
#   'get',
#   'concurrency',
#   'celery',
#   'developer',
#   'python',
#   'best_friend'],
#  ['womenareamazing',
#   'think',
#   'induoevents',
#   'superwomen',
#   'follow',
#   'dowhatyoulove'],
#  ['hairy', 'pussy', 'redtube', 'hardcore', 'track'],
#  ['let',
#   'season',
#   'binge',
#   'begin',
#   'oitnb',
#   'myfavorite',
#   'season',
#   'weekendplans'],
#  ['rest',
#   'peace',
#   'christinagrimmie',
#   'loss',
#   'rip',
#   'missed',
#   'fan',
#   'foreverinourheas',
#   'rest_peace'],
#  ['picture',
#   'woh',
#   'thousand',
#   'word',
#   'sundayrewind',
#   'hongkong',
#   'travel',
#   'lady',
#   'lawyer'],
#  ['relax',
#   'inger',
#   'followme',
#   'follow',
#   'follow',
#   '4follow',
#   'beach',
#   'pool',
#   'relax',
#   'enjoy',
#   'couple',
#   'followme_follow'],
#  ['countdown',
#   'begun',
#   'family',
#   'freeevent',
#   'festival',
#   'enteainment',
#   'food',
#   'stall'],
#  ['awesome', 'beginner', 'gopro', 'mount', 'super', 'use'],
#  ['dear',
#   'istore',
#   'please',
#   'crash',
#   'due',
#   'heavy',
#   'overload',
#   'booktime',
#   'muchlove'],
#  ['never',
#   'underestimate',
#   'power',
#   'good',
#   'book',
#   'good',
#   'wine',
#   'good',
#   'food',
#   'great',
#   'patio',
#   'summerevening',
#   'patioweather'],
#  ['istg', 'best', 'cheese', 'ta', 'dayum', 'expensive'],
#  ['morning', 'office', 'routine', 'never', 'without', 'bff', 'imy'],
#  ['model', 'love', 'take', 'time', 'ur', 'model_love', 'take_time'],
#  ['theshallows', 'weak', 'attempt', 'cash', 'jaw', 'anniversary'],
#  ['non',
#   'stop',
#   'election',
#   'blame',
#   'cspan',
#   'hiding',
#   'year',
#   'pittsburgh',
#   'california'],
#  ['extremely',
#   'reveal',
#   'first',
#   'official',
#   'poster',
#   'poalorigins',
#   'pa',
#   'coming',
#   'summer',
#   'mo'],
#  ['minute', 'counting', 'wwdc', 'wwdc'],
#  ['play', 'ball', 'state', 'politics', 'facade', 'lost', 'principality'],
#  ['people', 'protesting', 'trump', 'republican', 'trump', 'fuhered'],
#  ['great', 'day', 'nothing', 'happy', 'blessed', 'thankful'],
#  ['happy', 'sunday', 'everyone', 'sundaymorning', 'sunday', 'peace', 'love'],
#  ['always',
#   'help',
#   'others',
#   'never',
#   'people',
#   'matter',
#   'clearly',
#   'quote',
#   'latenights'],
#  ['bihday', 'weekend', 'even', 'better', 'xx'],
#  ['stay',
#   'strong',
#   'selflove',
#   'love',
#   'iloveme',
#   'quote',
#   'quote',
#   'quoteoftheday',
#   'happiness',
#   'life',
#   'wisdom',
#   'wordsofwisdom'],
#  ['happy',
#   'father',
#   'day',
#   'boy',
#   'father',
#   'sweet',
#   'love',
#   'memory',
#   'happy_father'],
#  ['aww',
#   'yeah',
#   'good',
#   'bing',
#   'bong',
#   'bing',
#   'bong',
#   'aww_yeah',
#   'good_bing',
#   'bong_bing'],
#  ['life',
#   'impoant',
#   'human',
#   'spirit',
#   'truth',
#   'love',
#   'give',
#   'spirituality',
#   'thinkbigsundaywithmarsha'],
#  ['father',
#   'baby',
#   'love',
#   'happiest',
#   'father',
#   'day',
#   'father',
#   'via',
#   'father_day'],
#  ['current', 'mood', 'web', 'developer', 'meet', 'hire'],
#  ['know', 'getting', 'old', 'sta', 'get', 'turned', 'looking', 'poweools'],
#  ['project', 'busy', 'hand', 'happy', 'hand'],
#  ['bride',
#   'woman',
#   'fine',
#   'prospect',
#   'happiness',
#   'behind',
#   'ambrose',
#   'bierce',
#   'wedding',
#   'love'],
#  ['friday', 'xoxosamantha', 'via'],
#  ['stop',
#   'robbing',
#   'innocent',
#   'customer',
#   'hard',
#   'earned',
#   'aiime',
#   'guy',
#   'idea',
#   'dey',
#   'managed',
#   'recharge'],
#  ['grab', 'bestie', 'swing', 'hour', 'missed', 'fun', 'eat'],
#  ['opinion',
#   'racism',
#   'degrading',
#   'people',
#   'based',
#   'race',
#   'justify',
#   'discrimination',
#   'open',
#   'violence',
#   'stopracism'],
#  ['finally', 'moving', 'today'],
#  ['way', 'say', 'blogger', 'vlogger'],
#  ['yay', 'fantastic', 'edinburgh'],
#  ['lemme', 'find', 'put', 'boiler', 'month', 'june'],
#  ['hea', 'go', 'family', 'people', 'killed', 'massacre', 'orlando'],
#  ['pre', 'gig', 'drink', 'passthecourvoisier'],
#  ['rescued',
#   'pup',
#   'meet',
#   'rexy',
#   'rescuepup',
#   'rexy',
#   'pupsofsg',
#   'suicidegirls',
#   'beautiful',
#   'puppylove'],
#  ['video',
#   'get',
#   'excited',
#   'future',
#   'tech',
#   'augmented',
#   'future',
#   'mobile'],
#  ['congrats', 'ur', 'wish', 'come', 'true', 'working', 'superxcited', 'song'],
#  ['wish'],
#  ['hellosunday', 'hope', 'beautiful', 'sunday', 'sundayfunday', 'sunnday'],
#  ['gif', 'listen', 'song', 'since', 'age'],
#  ['nzd',
#   'usd',
#   'rise',
#   'eyeing',
#   'gdt',
#   'price',
#   'index',
#   'fomc',
#   'statement',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['true',
#   'home',
#   'food',
#   'considered',
#   'cheap',
#   'meal',
#   'impression',
#   'made',
#   'restaurant'],
#  ['happy',
#   'bihday',
#   'one',
#   'west',
#   'greatest',
#   'tupac',
#   'shakur',
#   'bihday',
#   'rip',
#   'tupac',
#   'happy_bihday'],
#  ['live', 'life'],
#  ['29hrs',
#   'go',
#   'fl',
#   'motionposter',
#   'revealed',
#   'mupparimanam',
#   'feeling',
#   'nervous',
#   'stay',
#   'tuned'],
#  ['little', 'taste', 'sure'],
#  ['appletstag',
#   'compleanno',
#   'toa',
#   'cake',
#   'family',
#   'bday',
#   'selfie',
#   'smile',
#   'girl',
#   'summer'],
#  ['anime',
#   'anime',
#   'tree',
#   'friend',
#   'tag',
#   'anime',
#   'fana',
#   'pixiv',
#   'happy',
#   'tree'],
#  ['happy',
#   '2nd',
#   'wedding',
#   'anniversary',
#   'amazing',
#   'husband',
#   'memory',
#   '2years',
#   'lotstocome',
#   'love'],
#  ['slow',
#   'sta',
#   'productive',
#   'day',
#   'getting',
#   'back',
#   'routine',
#   'bout',
#   'fatigue',
#   'flareup',
#   'hard',
#   'spoonieproblems'],
#  ['love',
#   'ramdan',
#   'fasting',
#   'love',
#   'iftar',
#   'feeling',
#   'love',
#   'way',
#   'feel',
#   'ramadan',
#   'praying',
#   'reading',
#   'quran',
#   'blessed'],
#  ['eur',
#   'gbp',
#   'subdued',
#   'trading',
#   'action',
#   'around',
#   'blog',
#   'silver',
#   'gold',
#   'forex',
#   'blog_silver',
#   'gold_forex'],
#  ['ngitingtagumpay'],
#  ['unusual',
#   'cloudy',
#   'day',
#   'election',
#   'day',
#   'picnic',
#   'friend',
#   'sunday',
#   'everyone',
#   'welcomeludovica'],
#  ['cloudchaser',
#   'gorilla',
#   'simulator',
#   'need',
#   'adapt',
#   'environment',
#   'need',
#   'tear',
#   'city',
#   'mat',
#   'gorilla_simulator',
#   'need_adapt',
#   'environment_need',
#   'tear_city'],
#  ['christ',
#   'alive',
#   'vlicobs',
#   'xoxo',
#   'love',
#   'grace',
#   'amen',
#   'share',
#   'passion',
#   'church',
#   'life'],
#  ['want',
#   'leak',
#   'udta',
#   'punjab',
#   'probed',
#   'suspect',
#   'political',
#   'job',
#   'jobsearch',
#   'chandigarh',
#   'maker',
#   'udt'],
#  ['yesterday', 'ozen', 'restaurant', 'eatallyoucan'],
#  ['already',
#   'tell',
#   'next',
#   'week',
#   'episode',
#   'gonna',
#   'give',
#   'intense',
#   'anxiety',
#   'nervous',
#   'gameofthrones',
#   'next_week'],
#  ['got', 'nothing', 'say', 'assume', 'ahahahahahah'],
#  ['ordinary', 'girl', 'intruduceyourself'],
#  ['may',
#   'light',
#   'triumph',
#   'darkness',
#   'may',
#   'ramadan',
#   'bring',
#   'peace',
#   'harmony',
#   'joy',
#   'ramadan',
#   'ramadankareem'],
#  ['else',
#   'notice',
#   'suppoers',
#   'pageant',
#   'girl',
#   'year',
#   'internalize',
#   'female',
#   'oppressive',
#   'system'],
#  ['reason',
#   'optimist',
#   'rule',
#   'world',
#   'success',
#   'growth',
#   'balance',
#   'optimism'],
#  ['hate',
#   'online',
#   'application',
#   'even',
#   'get',
#   'foot',
#   'door',
#   'tell',
#   'need'],
#  ['thankful', 'flower', 'thankful', 'positive', 'thankful_positive'],
#  ['top',
#   'crappy',
#   'day',
#   'signing',
#   'paper',
#   'house',
#   'pop',
#   'conce',
#   'block',
#   'work',
#   'know'],
#  ['beautiful', 'love', 'living', 'beach', 'beach', 'loveit'],
#  ['omg',
#   'bitch',
#   'knew',
#   'gone',
#   'lil',
#   'kim',
#   'actually',
#   'look',
#   'like',
#   'music',
#   'video',
#   'look_like'],
#  ['tgif', 'ff', 'gamedev', 'indiedev', 'indiegamedev', 'squad'],
#  ['man', 'even', 'bunch', 'coupon'],
#  ['way', 'sta', 'day', 'goodmorning'],
#  ['lking', 'forward', 'watering', 'hole', 'watchtower', 'fore'],
#  ['allahsoil',
#   'next',
#   'best',
#   'seller',
#   'book',
#   'isi',
#   'islam',
#   '2016in4worlds',
#   '2016in4words',
#   'terrorist',
#   'gwot'],
#  ['fantastic',
#   'rub',
#   'steak',
#   'yum',
#   'thespicesndteaexchange',
#   'dc',
#   'healthy'],
#  ['followme', 'touch', 'tit'],
#  ['feel',
#   'like',
#   'summer',
#   'love',
#   'like',
#   'live',
#   'life',
#   'enjoy',
#   'healthy',
#   'sun',
#   'tan',
#   'bikini',
#   'summer',
#   'feel_like'],
#  ['teenageson',
#   'reckons',
#   'gone',
#   'beyond',
#   'call',
#   'duty',
#   'fathersday',
#   'prezzie'],
#  ['forget',
#   'research',
#   'show',
#   'sexist',
#   'men',
#   'psychological',
#   'problem',
#   'tuckercarlson'],
#  ['nice', 'specific', 'pedagogical', 'change'],
#  ['typical', 'city', 'fan'],
#  ['im',
#   'attracted',
#   'asian',
#   'ppl',
#   'bc',
#   'im',
#   'asian',
#   'tell',
#   'im',
#   'attracted',
#   'bc',
#   'im',
#   'inse',
#   'race',
#   'hoe'],
#  ['awlrite',
#   'mol',
#   'jealous',
#   'better',
#   'cricket',
#   'pitch',
#   'life',
#   'getalife'],
#  ['prayer', 'go', 'eddie', 'family'],
#  ['nothappy', 'carer', 'finishing', 'one', 'week'],
#  ['closeencounters',
#   'fatkind',
#   'fatkid',
#   'dese',
#   'sick',
#   'tired',
#   'maybemono'],
#  ['gymmorgon', 'gym', 'morning', 'strength', 'energy', 'training', 'wingym'],
#  ['glad', 'arrived', 'safely'],
#  ['defines',
#   'historically',
#   'oppressed',
#   'historic',
#   'oppressor',
#   'privileged'],
#  ['really',
#   'pretending',
#   'truthseekers',
#   'empowerment',
#   'selfimprovement',
#   'healing',
#   'ihearadio'],
#  ['finally',
#   'found',
#   'way',
#   'delete',
#   'old',
#   'tweet',
#   'might',
#   'find',
#   'useful',
#   'well',
#   'deletetweets',
#   'finally_found',
#   'way_delete',
#   'old_tweet',
#   'might_find',
#   'useful_well'],
#  ['view',
#   'oregon',
#   'poland',
#   'usa',
#   'unitedstates',
#   'holiday',
#   'dj',
#   'producer',
#   'house'],
#  ['put', 'vote', 'yet', 'havent', 'share', 'see', 'make', 'smile', 'poll'],
#  ['next',
#   'chapter',
#   'life',
#   'stas',
#   'soon',
#   'looking',
#   'house',
#   'today',
#   'fianc'],
#  ...]
